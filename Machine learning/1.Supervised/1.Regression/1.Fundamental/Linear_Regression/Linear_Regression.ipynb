# %% [markdown]
# ## Importing Essancial Libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np

# %% [markdown]
# ## Read Data

# %%
df = pd.read_csv('Study_vs_Score_data.csv')
df.head()
# Out:
#    Attendance_Hours  Final_Marks
# 0         36.217808    58.997409
# 1         76.550001    71.598279
# 2         61.239576    72.520777
# 3         51.906094    69.005976
# 4         20.921305    53.259605

# %% [markdown]
# ### EDA

# %%
plt.scatter(df['Attendance_Hours'], df['Final_Marks'])
plt.xlabel('Attendance_Hours')
plt.ylabel('Final_Marks')
plt.title('Study Hours vs Score')
plt.show()

# %% [markdown]
# ## Data Splitting

# %%
x = df[['Attendance_Hours']]
y = df['Final_Marks']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Data Preprocessing

# %%
Scalar = StandardScaler()
x_train = Scalar.fit_transform(x_train)
x_test = Scalar.transform(x_test)

# %% [markdown]
# ## Model Implementation

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predictions

# %%
y_pred = model.predict(x_test)
y_pred

# %% [markdown]
# ## Model Performance

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2}')
# Out:
# Mean Squared Error: 21.43431166454385
# R^2 Score: 0.8233456032324955

# %% [markdown]
# ## Model Verification

# %%
train_data = model.predict(x_train)
test_data = model.predict(x_test)
plt.scatter(x_train, y_train, color='blue', label='Train Data')
plt.scatter(x_test, y_test, color='green', label='Test Data')
plt.scatter(x_test, y_pred, color='red', label='Predictions')
plt.plot(x_train, train_data, color='black', label='Regression Line')
plt.xlabel('Attendance_Hours')
plt.ylabel('Final_Marks')
plt.title('Linear Regression Model')
plt.legend()
plt.show()

# %%
train_r2 = r2_score(y_train, train_data)
test_r2 = r2_score(y_test, y_pred)
print(f'Train R^2 Score: {train_r2}')
print(f'Test R^2 Score: {test_r2}')
# Out:
# Train R^2 Score: 0.798764468284938
# Test R^2 Score: 0.8233456032324955

# %% [markdown]
# <hr>
# <h3 style="color:#2E86C1;">Vamsi Sakepuram</h3>
# <p style="font-size:24px; color:#555;">Data Scientist</p>
# </hr>
